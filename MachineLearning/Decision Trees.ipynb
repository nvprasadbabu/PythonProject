# %% [markdown]
# <center><u><H1>Decision Trees</H1></u></center>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
# %matplotlib inline

# %%
iris = load_iris()

# %% [markdown]
# ## Preprocessing:

# %%
X = iris.data
y = iris.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=2018)

# %% [markdown]
# ## Creating a model

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)

# %% [markdown]
# ## Predictions:

# %%
dt.predict(iris.data[149:, :])

# %%
dt.predict_proba(iris.data[149:, :])

# %% [markdown]
# ## Cross Validation:

# %%
cross_val_score(dt, X_test, y_test, cv=10).mean()

# %% [markdown]
# ## Plotting Decision Boundaries:

# %%
def plot_regions(X, y, classifier):
    # Parameters
    n_classes = 3
    plot_colors = ["purple","orange","gray"]
    res = 0.02

    for pairidx, pair in enumerate([[0, 1], [0, 2], [0, 3],
                                [1, 2], [1, 3], [2, 3]]):
        
        X = iris.data[:, pair]
        # Train
        clf = classifier.fit(X, y)

        # Plot the decision boundary
        fig = plt.figure(1,figsize=(14, 10))
        plt.subplot(2, 3, pairidx + 1)

        x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
        y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
        xx, yy = np.meshgrid(np.arange(x_min, x_max, res),
                         np.arange(y_min, y_max, res))
        
        output = clf.predict(np.array([xx.ravel(), yy.ravel()]).T)
        output = output.reshape(xx.shape)
        plt.pcolormesh(xx,yy, output, cmap=plt.cm.Blues_r)
        
        plt.xlabel(iris.feature_names[pair[0]])
        plt.ylabel(iris.feature_names[pair[1]])
        
        # Plot the training points
        for nc, color in zip(range(n_classes), plot_colors):
            plt.scatter(X[y==nc, 0], X[y==nc, 1], c=color, label=iris.target_names[nc])
          
    plt.suptitle("Decision Tree")
    plt.legend(loc='best')
    plt.show()

# %%
new_dt = DecisionTreeClassifier()
plot_regions(X=iris.data,y=iris.target,classifier=new_dt)

# %% [markdown]
# ## Reference:
#
# http://scikit-learn.org/stable/modules/tree.html
#
# http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
