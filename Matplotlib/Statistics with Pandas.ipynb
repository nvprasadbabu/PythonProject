# %% [markdown]
# <center><u><H1>STATISTICS WITH PANDAS</H1></u></center>

# %%
import pandas as pd

# %%
df=pd.read_csv('../../data/iris.csv')
df[0:10]

# %%
#Descriptive statistics
df.describe()

# %%
# Lowest and highest value
df['SepalLengthCm'].max()

# %%
#Variance
df['PetalLengthCm'].var()

# %%
#Mean
df['PetalWidthCm'].mean()

# %%
#Median
df['PetalWidthCm'].median()

# %%
df['PetalWidthCm'][0:5].sum()

# %%
df['PetalWidthCm'][0:5].cumsum()

# %%
df['PetalLengthCm'][0:5].value_counts()

# %%
# %matplotlib inline
df['PetalLengthCm'].plot()

# %% [markdown]
# ## Reference:
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html
